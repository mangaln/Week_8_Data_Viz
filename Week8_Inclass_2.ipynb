# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
df=pd.read_csv("03-27-2020.csv.txt")
df.shape
# Out:
# (3429, 12)

# %%
df1=df[df.Confirmed!=0]
df1.head()
df1.sort_values(by='Confirmed',ascending=False)
# Out:
#          FIPS         Admin2 Province_State  Country_Region  \
# 3336      NaN            NaN            NaN           Italy
# 3206      NaN            NaN          Hubei           China
# 3403      NaN            NaN            NaN           Spain
# 3317      NaN            NaN            NaN         Germany
# 3313      NaN            NaN            NaN          France
# 3332      NaN            NaN            NaN            Iran
# 2066  36061.0  New York City       New York              US
# 3421      NaN            NaN            NaN  United Kingdom
# 3408      NaN            NaN            NaN     Switzerland
# 3342      NaN            NaN            NaN    Korea, South
# 3370      NaN            NaN            NaN     Netherlands
# 3265      NaN            NaN            NaN         Austria
# 3272      NaN            NaN            NaN         Belgium
# 3053  36119.0    Westchester       New York              US
# 3417      NaN            NaN            NaN          Turkey
# ...

# %%
conda install folium -c conda-forge
# Out:
# ...
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.07=py37_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\18132\Anaconda3
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         182 KB  conda-forge
#     certifi-2019.11.28         |   py37hc8dfbb8_1         149 KB  conda-forge
# ...

# %%
m = folium.Map(location=[20,0], tiles="Stamen Toner", zoom_start=2)
for LATITUDE, LONGITUDE,COUNTY, Confirmed in zip(df1['Lat'], df1['Long_'],df1['Combined_Key'],df1['Confirmed']):
    folium.CircleMarker([LATITUDE, LONGITUDE],
                        radius=Confirmed/1000,
                        color='red',
                         popup =('Combined_Key:' + str(COUNTY) + '<br>'
                             'Confirmed:' + str(Confirmed) + '<br>'
                           ),
                      
                        fill_color='red',
                        fill_opacity=0.7 ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
